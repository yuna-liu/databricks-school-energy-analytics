# %%
# %sql
CREATE SCHEMA IF NOT EXISTS school_energy_ml.bronze;
CREATE SCHEMA IF NOT EXISTS school_energy_ml.silver;
CREATE SCHEMA IF NOT EXISTS school_energy_ml.gold;
CREATE SCHEMA IF NOT EXISTS school_energy_ml.features;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS school_energy_ml.bronze.raw_energy;

# %% [markdown]
# bronze   → raw ingestion（volumn);
#
# silver   → clean + structured (dm + pivoted fact tables);
#
# gold     → ML / analytics ready (long / features)
